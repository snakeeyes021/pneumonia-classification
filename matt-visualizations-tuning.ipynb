# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
import os
import PIL
from IPython.display import Image

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, BatchNormalization, Conv2D, MaxPool2D, Dropout, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, array_to_img, img_to_array
from sklearn.metrics import confusion_matrix
from tensorflow.keras import datasets, layers, models
from keras_visualizer import visualizer

import pathlib
import time
import datetime
import pickle
import random

os.environ['PYTHONHASHSEED']=str(123)
random.seed(123)
np.random.seed(123)
tf.random.set_seed(123)

# %%
# Test to see whether you have all necessary libraries for GPU support
# If so, this should output a list with at least one GPU
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# If a GPU is present, the next cell should be run to limit the amount of allocated memory on the GPU only to that which is necessary.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# # Uploading the Data

# %%
train_dir = 'data/kaggle dataset/chest_xray/train'
test_dir = 'data/kaggle dataset/chest_xray/test'
val_dir = 'data/kaggle dataset/chest_xray/val'

# %%
train_norm_dir = os.path.join(train_dir, 'NORMAL')
train_pneu_dir = os.path.join(train_dir, 'PNEUMONIA')
val_norm_dir = os.path.join(val_dir, 'NORMAL')
val_pneu_dir = os.path.join(val_dir, 'PNEUMONIA')
test_norm_dir = os.path.join(test_dir, 'NORMAL')
test_pneu_dir = os.path.join(test_dir, 'PNEUMONIA')

# %%
len(os.listdir(train_norm_dir))
# Out:
# 1221

# %%
def picture(filepath):
    filenames = os.listdir(filepath)
    filepaths = [os.path.join(filepath, name) for name in filenames]
    return [img for img in filepaths]

# %%
train_norm_images = picture(train_norm_dir)
train_pneu_images = picture(train_pneu_dir)

# %%
PIL.Image.open(train_norm_images[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1422x1152 at 0x7FDBF0078130>

# %% [markdown]
# # Creating Test/Train Batches

# %%
# get all the data in the directory split/test (180 images), and reshape them
test_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
        test_dir, 
        target_size=(64, 64), batch_size = 180) 

# get all the data in the directory split/validation (200 images), and reshape them
val_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
        val_dir, 
        target_size=(64, 64), batch_size = 200)

# get all the data in the directory split/train (542 images), and reshape them
train_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
        train_dir, 
        target_size=(64, 64), batch_size=542)
# Out:
# Found 624 images belonging to 2 classes.
# Found 256 images belonging to 2 classes.
# Found 4976 images belonging to 2 classes.

# %%
# create the data sets
train_images, train_labels = next(train_generator)
test_images, test_labels = next(test_generator)
val_images, val_labels = next(val_generator)

# %%
# Explore your dataset again
m_train = train_images.shape[0]
num_px = train_images.shape[1]
m_test = test_images.shape[0]
m_val = val_images.shape[0]

print ("Number of training samples: " + str(m_train))
print ("Number of testing samples: " + str(m_test))
print ("Number of validation samples: " + str(m_val))
print ("train_images shape: " + str(train_images.shape))
print ("train_labels shape: " + str(train_labels.shape))
print ("test_images shape: " + str(test_images.shape))
print ("test_labels shape: " + str(test_labels.shape))
print ("val_images shape: " + str(val_images.shape))
print ("val_labels shape: " + str(val_labels.shape))
# Out:
# Number of training samples: 542
# Number of testing samples: 180
# Number of validation samples: 200
# train_images shape: (542, 64, 64, 3)
# train_labels shape: (542, 2)
# test_images shape: (180, 64, 64, 3)
# test_labels shape: (180, 2)
# val_images shape: (200, 64, 64, 3)
# val_labels shape: (200, 2)

# %%
train_img = train_images.reshape(train_images.shape[0], -1)
test_img = test_images.reshape(test_images.shape[0], -1)
val_img = val_images.reshape(val_images.shape[0], -1)

print(train_img.shape)
print(test_img.shape)
print(val_img.shape)
# Out:
# (542, 12288)
# (180, 12288)
# (200, 12288)

# %%
train_y = np.reshape(train_labels[:,0], (542,1))
test_y = np.reshape(test_labels[:,0], (180,1))
val_y = np.reshape(val_labels[:,0], (200,1))

# %% [markdown]
# # Baseline Model

# %%
model = models.Sequential()
model.add(layers.Dense(20, activation='relu', input_shape=(12288,))) # 2 hidden layers
model.add(layers.Dense(7, activation='relu'))
model.add(layers.Dense(5, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

base_model = model.fit(train_img,
                    train_y,
                    epochs=50,
                    batch_size=32,
                    validation_data=(val_img, val_y))
# Out:
# Epoch 1/50
# 17/17 [==============================] - 1s 18ms/step - loss: 0.6918 - accuracy: 0.7325 - val_loss: 0.6929 - val_accuracy: 0.5200
# Epoch 2/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6871 - accuracy: 0.7509 - val_loss: 0.6926 - val_accuracy: 0.5200
# Epoch 3/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.6831 - accuracy: 0.7509 - val_loss: 0.6925 - val_accuracy: 0.5200
# Epoch 4/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6794 - accuracy: 0.7509 - val_loss: 0.6924 - val_accuracy: 0.5200
# Epoch 5/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6757 - accuracy: 0.7509 - val_loss: 0.6923 - val_accuracy: 0.5200
# Epoch 6/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.6721 - accuracy: 0.7509 - val_loss: 0.6924 - val_accuracy: 0.5200
# Epoch 7/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6685 - accuracy: 0.7509 - val_loss: 0.6925 - val_accuracy: 0.5200
# Epoch 8/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6652 - accuracy: 0.7509 - val_loss: 0.6926 - val_accuracy: 0.5200
# Epoch 9/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6619 - accuracy: 0.7509 - val_loss: 0.6928 - val_accuracy: 0.5200
# Epoch 10/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.6585 - accuracy: 0.7509 - val_loss: 0.6931 - val_accuracy: 0.5200
# Epoch 11/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6555 - accuracy: 0.7509 - val_loss: 0.6934 - val_accuracy: 0.5200
# Epoch 12/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6523 - accuracy: 0.7509 - val_loss: 0.6938 - val_accuracy: 0.5200
# Epoch 13/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6493 - accuracy: 0.7509 - val_loss: 0.6942 - val_accuracy: 0.5200
# Epoch 14/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6464 - accuracy: 0.7509 - val_loss: 0.6946 - val_accuracy: 0.5200
# Epoch 15/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6436 - accuracy: 0.7509 - val_loss: 0.6951 - val_accuracy: 0.5200
# Epoch 16/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6409 - accuracy: 0.7509 - val_loss: 0.6957 - val_accuracy: 0.5200
# Epoch 17/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6381 - accuracy: 0.7509 - val_loss: 0.6963 - val_accuracy: 0.5200
# Epoch 18/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.6355 - accuracy: 0.7509 - val_loss: 0.6969 - val_accuracy: 0.5200
# Epoch 19/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6331 - accuracy: 0.7509 - val_loss: 0.6976 - val_accuracy: 0.5200
# Epoch 20/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6306 - accuracy: 0.7509 - val_loss: 0.6983 - val_accuracy: 0.5200
# Epoch 21/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6282 - accuracy: 0.7509 - val_loss: 0.6990 - val_accuracy: 0.5200
# Epoch 22/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6258 - accuracy: 0.7509 - val_loss: 0.6998 - val_accuracy: 0.5200
# Epoch 23/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.6238 - accuracy: 0.7509 - val_loss: 0.7007 - val_accuracy: 0.5200
# Epoch 24/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6214 - accuracy: 0.7509 - val_loss: 0.7015 - val_accuracy: 0.5200
# Epoch 25/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6193 - accuracy: 0.7509 - val_loss: 0.7023 - val_accuracy: 0.5200
# Epoch 26/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6173 - accuracy: 0.7509 - val_loss: 0.7032 - val_accuracy: 0.5200
# Epoch 27/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6154 - accuracy: 0.7509 - val_loss: 0.7042 - val_accuracy: 0.5200
# Epoch 28/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6133 - accuracy: 0.7509 - val_loss: 0.7052 - val_accuracy: 0.5200
# Epoch 29/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.6115 - accuracy: 0.7509 - val_loss: 0.7061 - val_accuracy: 0.5200
# Epoch 30/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6097 - accuracy: 0.7509 - val_loss: 0.7072 - val_accuracy: 0.5200
# Epoch 31/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6079 - accuracy: 0.7509 - val_loss: 0.7082 - val_accuracy: 0.5200
# Epoch 32/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6062 - accuracy: 0.7509 - val_loss: 0.7093 - val_accuracy: 0.5200
# Epoch 33/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6045 - accuracy: 0.7509 - val_loss: 0.7103 - val_accuracy: 0.5200
# Epoch 34/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.6029 - accuracy: 0.7509 - val_loss: 0.7114 - val_accuracy: 0.5200
# Epoch 35/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.6014 - accuracy: 0.7509 - val_loss: 0.7125 - val_accuracy: 0.5200
# Epoch 36/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5999 - accuracy: 0.7509 - val_loss: 0.7137 - val_accuracy: 0.5200
# Epoch 37/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5984 - accuracy: 0.7509 - val_loss: 0.7148 - val_accuracy: 0.5200
# Epoch 38/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.5971 - accuracy: 0.7509 - val_loss: 0.7161 - val_accuracy: 0.5200
# Epoch 39/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5956 - accuracy: 0.7509 - val_loss: 0.7172 - val_accuracy: 0.5200
# Epoch 40/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5943 - accuracy: 0.7509 - val_loss: 0.7184 - val_accuracy: 0.5200
# Epoch 41/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5930 - accuracy: 0.7509 - val_loss: 0.7196 - val_accuracy: 0.5200
# Epoch 42/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.5918 - accuracy: 0.7509 - val_loss: 0.7208 - val_accuracy: 0.5200
# Epoch 43/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5907 - accuracy: 0.7509 - val_loss: 0.7221 - val_accuracy: 0.5200
# Epoch 44/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5895 - accuracy: 0.7509 - val_loss: 0.7233 - val_accuracy: 0.5200
# Epoch 45/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5884 - accuracy: 0.7509 - val_loss: 0.7245 - val_accuracy: 0.5200
# Epoch 46/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5873 - accuracy: 0.7509 - val_loss: 0.7257 - val_accuracy: 0.5200
# Epoch 47/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5863 - accuracy: 0.7509 - val_loss: 0.7269 - val_accuracy: 0.5200
# Epoch 48/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5853 - accuracy: 0.7509 - val_loss: 0.7283 - val_accuracy: 0.5200
# Epoch 49/50
# 17/17 [==============================] - 0s 7ms/step - loss: 0.5843 - accuracy: 0.7509 - val_loss: 0.7294 - val_accuracy: 0.5200
# Epoch 50/50
# 17/17 [==============================] - 0s 8ms/step - loss: 0.5834 - accuracy: 0.7509 - val_loss: 0.7307 - val_accuracy: 0.5200

# %%
results_train = model.evaluate(train_img, train_y)
# Out:
# 17/17 [==============================] - 0s 4ms/step - loss: 0.5829 - accuracy: 0.7509

# %%
results_test = model.evaluate(test_img, test_y)
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6830 - accuracy: 0.5944

# %%
results_test
# Out:
# [0.6830424070358276, 0.5944444537162781]

# %%
visualizer(model, filename='graphs/baseline', format='png')

# %%
Image('graphs/baseline.png')

# %% [markdown]
# Build your own CNN

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(64 ,64,  3)))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(32, (4, 4), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer="adam",
              metrics=['acc'])

# %%
cnn1 = model.fit(train_images,
                    train_y,
                    epochs=30,
                    batch_size=32,
                    validation_data=(val_images, val_y))
# Out:
# Epoch 1/30
# 17/17 [==============================] - 3s 84ms/step - loss: 0.6078 - acc: 0.7325 - val_loss: 0.8436 - val_acc: 0.5200
# Epoch 2/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.5573 - acc: 0.7509 - val_loss: 0.6984 - val_acc: 0.5200
# Epoch 3/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.4733 - acc: 0.7583 - val_loss: 0.7983 - val_acc: 0.5250
# Epoch 4/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.3707 - acc: 0.8303 - val_loss: 0.4449 - val_acc: 0.8650
# Epoch 5/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.3010 - acc: 0.8616 - val_loss: 0.3967 - val_acc: 0.8350
# Epoch 6/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.2270 - acc: 0.9077 - val_loss: 0.3540 - val_acc: 0.8400
# Epoch 7/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.2782 - acc: 0.8690 - val_loss: 0.5955 - val_acc: 0.7050
# Epoch 8/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.2259 - acc: 0.9114 - val_loss: 0.3291 - val_acc: 0.8550
# Epoch 9/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.2020 - acc: 0.9170 - val_loss: 0.2254 - val_acc: 0.9250
# Epoch 10/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.1525 - acc: 0.9428 - val_loss: 0.2336 - val_acc: 0.9000
# Epoch 11/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.1544 - acc: 0.9391 - val_loss: 0.3541 - val_acc: 0.8600
# Epoch 12/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.1480 - acc: 0.9483 - val_loss: 0.1922 - val_acc: 0.9350
# Epoch 13/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.1241 - acc: 0.9483 - val_loss: 0.1834 - val_acc: 0.9250
# Epoch 14/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.1158 - acc: 0.9539 - val_loss: 0.1779 - val_acc: 0.9250
# Epoch 15/30
# 17/17 [==============================] - 1s 36ms/step - loss: 0.0918 - acc: 0.9631 - val_loss: 0.2206 - val_acc: 0.9150
# Epoch 16/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.1166 - acc: 0.9539 - val_loss: 0.3738 - val_acc: 0.8700
# Epoch 17/30
# 17/17 [==============================] - 1s 36ms/step - loss: 0.1415 - acc: 0.9428 - val_loss: 0.3495 - val_acc: 0.8650
# Epoch 18/30
# 17/17 [==============================] - 1s 36ms/step - loss: 0.1455 - acc: 0.9576 - val_loss: 0.1845 - val_acc: 0.9300
# Epoch 19/30
# 17/17 [==============================] - 1s 36ms/step - loss: 0.1038 - acc: 0.9649 - val_loss: 0.1707 - val_acc: 0.9300
# Epoch 20/30
# 17/17 [==============================] - 1s 36ms/step - loss: 0.0860 - acc: 0.9668 - val_loss: 0.2174 - val_acc: 0.9150
# Epoch 21/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.0905 - acc: 0.9705 - val_loss: 0.3013 - val_acc: 0.8900
# Epoch 22/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.0664 - acc: 0.9815 - val_loss: 0.2045 - val_acc: 0.9250
# Epoch 23/30
# 17/17 [==============================] - 1s 36ms/step - loss: 0.0542 - acc: 0.9834 - val_loss: 0.2130 - val_acc: 0.9250
# Epoch 24/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.0506 - acc: 0.9871 - val_loss: 0.1838 - val_acc: 0.9150
# Epoch 25/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.0582 - acc: 0.9742 - val_loss: 0.2736 - val_acc: 0.9000
# Epoch 26/30
# 17/17 [==============================] - 1s 36ms/step - loss: 0.0554 - acc: 0.9852 - val_loss: 0.1704 - val_acc: 0.9250
# Epoch 27/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.0565 - acc: 0.9760 - val_loss: 0.2542 - val_acc: 0.9100
# Epoch 28/30
# 17/17 [==============================] - 1s 36ms/step - loss: 0.0481 - acc: 0.9852 - val_loss: 0.2215 - val_acc: 0.9100
# Epoch 29/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.0284 - acc: 0.9908 - val_loss: 0.2545 - val_acc: 0.9250
# Epoch 30/30
# 17/17 [==============================] - 1s 37ms/step - loss: 0.0238 - acc: 0.9926 - val_loss: 0.2657 - val_acc: 0.9150

# %%
results_train = model.evaluate(train_images, train_y)
# Out:
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0194 - acc: 0.9963

# %%
results_test = model.evaluate(test_images, test_y)
# Out:
# 6/6 [==============================] - 0s 44ms/step - loss: 1.4109 - acc: 0.7556

# %%
visualizer(model, filename='graphs/cnn1', format='png')

# %%
Image('graphs/cnn1.png')
