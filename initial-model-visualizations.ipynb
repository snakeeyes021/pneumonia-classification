# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
import os
import PIL
from IPython.display import Image

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense, BatchNormalization, Conv2D, MaxPool2D, Dropout, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, array_to_img, img_to_array
from sklearn.metrics import confusion_matrix
from tensorflow.keras import datasets, layers, models
from keras_visualizer import visualizer

import pathlib
import time
import datetime
import pickle
import random

os.environ['PYTHONHASHSEED']=str(123)
random.seed(123)
np.random.seed(123)
tf.random.set_seed(123)

# %%
# Test to see whether you have all necessary libraries for GPU support
# If so, this should output a list with at least one GPU
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# If a GPU is present, the next cell should be run to limit the amount of allocated memory on the GPU only to that which is necessary.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# # Organizing the data

# %%
train_dir = 'data/kaggle dataset/chest_xray/train'
test_dir = 'data/kaggle dataset/chest_xray/test'
val_dir = 'data/kaggle dataset/chest_xray/val'

# %%
train_norm_dir = os.path.join(train_dir, 'NORMAL')
train_pneu_dir = os.path.join(train_dir, 'PNEUMONIA')
val_norm_dir = os.path.join(val_dir, 'NORMAL')
val_pneu_dir = os.path.join(val_dir, 'PNEUMONIA')
test_norm_dir = os.path.join(test_dir, 'NORMAL')
test_pneu_dir = os.path.join(test_dir, 'PNEUMONIA')

# %%
len(os.listdir(train_norm_dir))
# Out:
# 1221

# %%
def picture(filepath):
    filenames = os.listdir(filepath)
    filepaths = [os.path.join(filepath, name) for name in filenames]
    return [img for img in filepaths]

# %%
train_norm_images = picture(train_norm_dir)
train_pneu_images = picture(train_pneu_dir)

# %%
PIL.Image.open(train_norm_images[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1422x1152 at 0x7F73106FA850>

# %%
PIL.Image.open(train_pneu_images[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1152x760 at 0x7F73106FA8E0>

# %% [markdown]
# # Creating Test/Train Batches

# %%
# get all the data in the directory split/test (180 images), and reshape them
test_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
        test_dir, 
        target_size=(256, 256), batch_size = 180) 

# get all the data in the directory split/validation (200 images), and reshape them
val_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
        val_dir, 
        target_size=(256, 256), batch_size = 200)

# get all the data in the directory split/train (542 images), and reshape them
train_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
        train_dir, 
        target_size=(256, 256), batch_size=542)
# Out:
# Found 624 images belonging to 2 classes.
# Found 256 images belonging to 2 classes.
# Found 4976 images belonging to 2 classes.

# %%
# create the data sets
train_images, train_labels = next(train_generator)
test_images, test_labels = next(test_generator)
val_images, val_labels = next(val_generator)

# %%
plt.figure(figsize=(10,10))

for i in range(9):
    ax = plt.subplot(3, 3, i+1)
    plt.imshow(array_to_img(train_images[i+250]))
    plt.title(int(train_labels[i+250][1]));

# %%
# Explore your dataset again
m_train = train_images.shape[0]
num_px = train_images.shape[1]
m_test = test_images.shape[0]
m_val = val_images.shape[0]

print ("Number of training samples: " + str(m_train))
print ("Number of testing samples: " + str(m_test))
print ("Number of validation samples: " + str(m_val))
print ("train_images shape: " + str(train_images.shape))
print ("train_labels shape: " + str(train_labels.shape))
print ("test_images shape: " + str(test_images.shape))
print ("test_labels shape: " + str(test_labels.shape))
print ("val_images shape: " + str(val_images.shape))
print ("val_labels shape: " + str(val_labels.shape))
# Out:
# Number of training samples: 542
# Number of testing samples: 180
# Number of validation samples: 200
# train_images shape: (542, 256, 256, 3)
# train_labels shape: (542, 2)
# test_images shape: (180, 256, 256, 3)
# test_labels shape: (180, 2)
# val_images shape: (200, 256, 256, 3)
# val_labels shape: (200, 2)

# %%
train_img = train_images.reshape(train_images.shape[0], -1)
test_img = test_images.reshape(test_images.shape[0], -1)
val_img = val_images.reshape(val_images.shape[0], -1)

print(train_img.shape)
print(test_img.shape)
print(val_img.shape)
# Out:
# (542, 196608)
# (180, 196608)
# (200, 196608)

# %%
train_y = np.reshape(train_labels[:,0], (542,1))
test_y = np.reshape(test_labels[:,0], (180,1))
val_y = np.reshape(val_labels[:,0], (200,1))

# %% [markdown]
# # Baseline Model

# %%
baseline = models.Sequential()
baseline.add(layers.Dense(20, activation='relu', input_shape=(196608,))) # 2 hidden layers
baseline.add(layers.Dense(7, activation='relu'))
baseline.add(layers.Dense(5, activation='relu'))
baseline.add(layers.Dense(1, activation='sigmoid'))

# %%
baseline.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

baseline_history = baseline.fit(train_img,
                    train_y,
                    epochs=50,
                    batch_size=32,
                    validation_data=(val_img, val_y))
# Out:
# Epoch 1/50
# 17/17 [==============================] - 2s 69ms/step - loss: 1.7221 - accuracy: 0.6384 - val_loss: 0.7609 - val_accuracy: 0.5200
# Epoch 2/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.4757 - accuracy: 0.7731 - val_loss: 0.5242 - val_accuracy: 0.7750
# Epoch 3/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.3619 - accuracy: 0.8690 - val_loss: 0.4771 - val_accuracy: 0.8200
# Epoch 4/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.3225 - accuracy: 0.8838 - val_loss: 0.4443 - val_accuracy: 0.8250
# Epoch 5/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.2934 - accuracy: 0.8948 - val_loss: 0.5475 - val_accuracy: 0.7000
# Epoch 6/50
# 17/17 [==============================] - 1s 51ms/step - loss: 0.2720 - accuracy: 0.8856 - val_loss: 0.4245 - val_accuracy: 0.8000
# Epoch 7/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.2404 - accuracy: 0.9133 - val_loss: 0.6060 - val_accuracy: 0.6650
# Epoch 8/50
# 17/17 [==============================] - 1s 51ms/step - loss: 0.2476 - accuracy: 0.9077 - val_loss: 0.4204 - val_accuracy: 0.8250
# Epoch 9/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.2346 - accuracy: 0.9004 - val_loss: 0.2957 - val_accuracy: 0.8950
# Epoch 10/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.1905 - accuracy: 0.9354 - val_loss: 0.3049 - val_accuracy: 0.8900
# Epoch 11/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.1818 - accuracy: 0.9280 - val_loss: 0.4538 - val_accuracy: 0.7850
# Epoch 12/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.1741 - accuracy: 0.9299 - val_loss: 0.2539 - val_accuracy: 0.9300
# Epoch 13/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.1818 - accuracy: 0.9336 - val_loss: 0.2438 - val_accuracy: 0.9250
# Epoch 14/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.1624 - accuracy: 0.9354 - val_loss: 0.2355 - val_accuracy: 0.9250
# Epoch 15/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.1435 - accuracy: 0.9502 - val_loss: 0.2369 - val_accuracy: 0.9200
# Epoch 16/50
# 17/17 [==============================] - 1s 60ms/step - loss: 0.1585 - accuracy: 0.9465 - val_loss: 0.5785 - val_accuracy: 0.7400
# Epoch 17/50
# 17/17 [==============================] - 1s 53ms/step - loss: 0.1364 - accuracy: 0.9557 - val_loss: 0.2249 - val_accuracy: 0.9300
# Epoch 18/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.1211 - accuracy: 0.9594 - val_loss: 0.3334 - val_accuracy: 0.8750
# Epoch 19/50
# 17/17 [==============================] - 1s 51ms/step - loss: 0.1223 - accuracy: 0.9576 - val_loss: 0.2253 - val_accuracy: 0.9150
# Epoch 20/50
# 17/17 [==============================] - 1s 51ms/step - loss: 0.1197 - accuracy: 0.9613 - val_loss: 0.2812 - val_accuracy: 0.8950
# Epoch 21/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.1101 - accuracy: 0.9594 - val_loss: 0.2749 - val_accuracy: 0.8950
# Epoch 22/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.1242 - accuracy: 0.9520 - val_loss: 0.2651 - val_accuracy: 0.8900
# Epoch 23/50
# 17/17 [==============================] - 1s 53ms/step - loss: 0.1127 - accuracy: 0.9557 - val_loss: 0.2328 - val_accuracy: 0.9050
# Epoch 24/50
# 17/17 [==============================] - 1s 51ms/step - loss: 0.1135 - accuracy: 0.9613 - val_loss: 0.2168 - val_accuracy: 0.9200
# Epoch 25/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.1000 - accuracy: 0.9594 - val_loss: 0.2245 - val_accuracy: 0.9150
# Epoch 26/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0893 - accuracy: 0.9705 - val_loss: 0.4736 - val_accuracy: 0.8200
# Epoch 27/50
# 17/17 [==============================] - 1s 55ms/step - loss: 0.0905 - accuracy: 0.9649 - val_loss: 0.2843 - val_accuracy: 0.8900
# Epoch 28/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0776 - accuracy: 0.9760 - val_loss: 0.4542 - val_accuracy: 0.8400
# Epoch 29/50
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0937 - accuracy: 0.9668 - val_loss: 0.2582 - val_accuracy: 0.8900
# Epoch 30/50
# 17/17 [==============================] - 1s 54ms/step - loss: 0.0695 - accuracy: 0.9779 - val_loss: 0.2059 - val_accuracy: 0.9300
# Epoch 31/50
# 17/17 [==============================] - 1s 55ms/step - loss: 0.0803 - accuracy: 0.9760 - val_loss: 0.2116 - val_accuracy: 0.9300
# Epoch 32/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0827 - accuracy: 0.9686 - val_loss: 0.2113 - val_accuracy: 0.9200
# Epoch 33/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0761 - accuracy: 0.9797 - val_loss: 0.2145 - val_accuracy: 0.9100
# Epoch 34/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0671 - accuracy: 0.9760 - val_loss: 0.2370 - val_accuracy: 0.9050
# Epoch 35/50
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0699 - accuracy: 0.9779 - val_loss: 0.3245 - val_accuracy: 0.8900
# Epoch 36/50
# 17/17 [==============================] - 1s 53ms/step - loss: 0.1659 - accuracy: 0.9299 - val_loss: 0.3314 - val_accuracy: 0.8900
# Epoch 37/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.1255 - accuracy: 0.9483 - val_loss: 0.2286 - val_accuracy: 0.9250
# Epoch 38/50
# 17/17 [==============================] - 1s 51ms/step - loss: 0.0892 - accuracy: 0.9649 - val_loss: 0.2213 - val_accuracy: 0.9200
# Epoch 39/50
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0742 - accuracy: 0.9668 - val_loss: 0.2332 - val_accuracy: 0.9250
# Epoch 40/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.1300 - accuracy: 0.9446 - val_loss: 0.2514 - val_accuracy: 0.9100
# Epoch 41/50
# 17/17 [==============================] - 1s 51ms/step - loss: 0.0831 - accuracy: 0.9649 - val_loss: 0.6150 - val_accuracy: 0.8100
# Epoch 42/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0492 - accuracy: 0.9815 - val_loss: 0.2433 - val_accuracy: 0.9200
# Epoch 43/50
# 17/17 [==============================] - 1s 51ms/step - loss: 0.0418 - accuracy: 0.9926 - val_loss: 0.2820 - val_accuracy: 0.8950
# Epoch 44/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0383 - accuracy: 0.9908 - val_loss: 0.2256 - val_accuracy: 0.9200
# Epoch 45/50
# 17/17 [==============================] - 1s 56ms/step - loss: 0.0473 - accuracy: 0.9852 - val_loss: 0.3548 - val_accuracy: 0.9000
# Epoch 46/50
# 17/17 [==============================] - 1s 51ms/step - loss: 0.0856 - accuracy: 0.9594 - val_loss: 0.4511 - val_accuracy: 0.8750
# Epoch 47/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0810 - accuracy: 0.9594 - val_loss: 0.6900 - val_accuracy: 0.7950
# Epoch 48/50
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0795 - accuracy: 0.9668 - val_loss: 0.2823 - val_accuracy: 0.9000
# Epoch 49/50
# 17/17 [==============================] - 1s 53ms/step - loss: 0.0468 - accuracy: 0.9852 - val_loss: 0.2287 - val_accuracy: 0.9250
# Epoch 50/50
# 17/17 [==============================] - 1s 52ms/step - loss: 0.0476 - accuracy: 0.9871 - val_loss: 0.3250 - val_accuracy: 0.9000

# %%
results_train = baseline.evaluate(train_img, train_y)
# Out:
# 17/17 [==============================] - 1s 29ms/step - loss: 0.0281 - accuracy: 0.9963

# %%
results_test = baseline.evaluate(test_img, test_y)
# Out:
# 6/6 [==============================] - 0s 27ms/step - loss: 1.0331 - accuracy: 0.7278

# %%
results_test
# Out:
# [1.0330537557601929, 0.7277777791023254]

# %%
visualizer(baseline, filename='graphs/baseline', format='png')

# %%
Image('graphs/baseline.png')

# %% [markdown]
# Build your own CNN

# %%
cnn1 = models.Sequential()
cnn1.add(layers.Conv2D(32, (3, 3), activation='relu',
                        input_shape=(256 ,256,  3)))
cnn1.add(layers.MaxPooling2D((2, 2)))

cnn1.add(layers.Conv2D(32, (4, 4), activation='relu'))
cnn1.add(layers.MaxPooling2D((2, 2)))

cnn1.add(layers.Conv2D(64, (3, 3), activation='relu'))
cnn1.add(layers.MaxPooling2D((2, 2)))

cnn1.add(layers.Flatten())
cnn1.add(layers.Dense(64, activation='relu'))
cnn1.add(layers.Dense(1, activation='sigmoid'))

cnn1.compile(loss='binary_crossentropy',
              optimizer="adam",
              metrics=['acc'])

# %%
cnn1_history = cnn1.fit(train_images,
                    train_y,
                    epochs=30,
                    batch_size=16,
                    validation_data=(val_images, val_y))
# Out:
# Epoch 1/30
# 34/34 [==============================] - 15s 377ms/step - loss: 0.5660 - acc: 0.7528 - val_loss: 0.5776 - val_acc: 0.7050
# Epoch 2/30
# 34/34 [==============================] - 11s 315ms/step - loss: 0.3388 - acc: 0.8745 - val_loss: 0.4339 - val_acc: 0.7650
# Epoch 3/30
# 34/34 [==============================] - 11s 313ms/step - loss: 0.2757 - acc: 0.8672 - val_loss: 0.2891 - val_acc: 0.8800
# Epoch 4/30
# 34/34 [==============================] - 11s 312ms/step - loss: 0.1909 - acc: 0.9188 - val_loss: 0.2288 - val_acc: 0.9000
# Epoch 5/30
# 34/34 [==============================] - 11s 313ms/step - loss: 0.1145 - acc: 0.9576 - val_loss: 0.2398 - val_acc: 0.9100
# Epoch 6/30
# 34/34 [==============================] - 11s 314ms/step - loss: 0.0824 - acc: 0.9760 - val_loss: 0.2260 - val_acc: 0.9050
# Epoch 7/30
# 34/34 [==============================] - 11s 313ms/step - loss: 0.0471 - acc: 0.9871 - val_loss: 0.2118 - val_acc: 0.9250
# Epoch 8/30
# 34/34 [==============================] - 11s 313ms/step - loss: 0.0262 - acc: 0.9945 - val_loss: 0.3150 - val_acc: 0.8700
# Epoch 9/30
# 34/34 [==============================] - 11s 313ms/step - loss: 0.0189 - acc: 0.9889 - val_loss: 0.2077 - val_acc: 0.9150
# Epoch 10/30
# 34/34 [==============================] - 11s 313ms/step - loss: 0.0080 - acc: 1.0000 - val_loss: 0.1944 - val_acc: 0.9400
# Epoch 11/30
# 34/34 [==============================] - 11s 314ms/step - loss: 0.0015 - acc: 1.0000 - val_loss: 0.1997 - val_acc: 0.9450
# Epoch 12/30
# 34/34 [==============================] - 11s 315ms/step - loss: 8.7475e-04 - acc: 1.0000 - val_loss: 0.2034 - val_acc: 0.9350
# Epoch 13/30
# 34/34 [==============================] - 11s 314ms/step - loss: 4.8435e-04 - acc: 1.0000 - val_loss: 0.2384 - val_acc: 0.9450
# Epoch 14/30
# 34/34 [==============================] - 11s 315ms/step - loss: 2.6849e-04 - acc: 1.0000 - val_loss: 0.3091 - val_acc: 0.9250
# Epoch 15/30
# 34/34 [==============================] - 11s 315ms/step - loss: 3.4187e-04 - acc: 1.0000 - val_loss: 0.2989 - val_acc: 0.9300
# Epoch 16/30
# 34/34 [==============================] - 11s 316ms/step - loss: 1.8118e-04 - acc: 1.0000 - val_loss: 0.2491 - val_acc: 0.9400
# Epoch 17/30
# 34/34 [==============================] - 11s 316ms/step - loss: 1.4278e-04 - acc: 1.0000 - val_loss: 0.2877 - val_acc: 0.9350
# Epoch 18/30
# 34/34 [==============================] - 11s 315ms/step - loss: 1.2823e-04 - acc: 1.0000 - val_loss: 0.2869 - val_acc: 0.9350
# Epoch 19/30
# 34/34 [==============================] - 11s 315ms/step - loss: 1.0408e-04 - acc: 1.0000 - val_loss: 0.2683 - val_acc: 0.9350
# Epoch 20/30
# 34/34 [==============================] - 11s 315ms/step - loss: 9.8343e-05 - acc: 1.0000 - val_loss: 0.2869 - val_acc: 0.9350
# Epoch 21/30
# 34/34 [==============================] - 11s 315ms/step - loss: 8.2538e-05 - acc: 1.0000 - val_loss: 0.2824 - val_acc: 0.9300
# Epoch 22/30
# 34/34 [==============================] - 11s 316ms/step - loss: 7.4183e-05 - acc: 1.0000 - val_loss: 0.2852 - val_acc: 0.9300
# Epoch 23/30
# 34/34 [==============================] - 11s 316ms/step - loss: 6.7576e-05 - acc: 1.0000 - val_loss: 0.3008 - val_acc: 0.9350
# Epoch 24/30
# 34/34 [==============================] - 11s 315ms/step - loss: 6.0730e-05 - acc: 1.0000 - val_loss: 0.2857 - val_acc: 0.9300
# Epoch 25/30
# 34/34 [==============================] - 11s 315ms/step - loss: 5.4690e-05 - acc: 1.0000 - val_loss: 0.3052 - val_acc: 0.9350
# Epoch 26/30
# 34/34 [==============================] - 11s 315ms/step - loss: 5.4715e-05 - acc: 1.0000 - val_loss: 0.2876 - val_acc: 0.9300
# Epoch 27/30
# 34/34 [==============================] - 11s 316ms/step - loss: 5.1713e-05 - acc: 1.0000 - val_loss: 0.3011 - val_acc: 0.9300
# Epoch 28/30
# 34/34 [==============================] - 11s 315ms/step - loss: 4.4827e-05 - acc: 1.0000 - val_loss: 0.3213 - val_acc: 0.9350
# Epoch 29/30
# 34/34 [==============================] - 11s 316ms/step - loss: 4.1121e-05 - acc: 1.0000 - val_loss: 0.3185 - val_acc: 0.9350
# Epoch 30/30
# 34/34 [==============================] - 11s 316ms/step - loss: 3.7170e-05 - acc: 1.0000 - val_loss: 0.3135 - val_acc: 0.9300

# %%
results_train = cnn1.evaluate(train_images, train_y)
# Out:
# 17/17 [==============================] - 3s 163ms/step - loss: 3.3733e-05 - acc: 1.0000

# %%
results_test = cnn1.evaluate(test_images, test_y)
# Out:
# 6/6 [==============================] - 1s 150ms/step - loss: 2.9182 - acc: 0.7167

# %%
visualizer(cnn1, filename='graphs/cnn1', format='png')

# %%
Image('graphs/cnn1.png')
